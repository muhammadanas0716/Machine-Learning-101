# %% [markdown]
# Done watching section on Workflows in PyTorch, bascially creating a PyTorch model and doing some sort of linear regression task.
#
# Now I will be using a sample dataset to test my knowledge, yes it does ha
