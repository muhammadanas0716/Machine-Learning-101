# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("gurgaon_properties.csv")
df.sample(5)
# Out:
#                                          property_name property_type  \
# 3745                  2 BHK Flat in Sector 107 Gurgaon          flat
# 1683  16 Bedroom House for sale in Sushant Lok Phase 2         house
# 963                    4 BHK Flat in Sector 60 Gurgaon          flat
# 2055                  3 BHK Flat in Sector 102 Gurgaon          flat
# 77                     3 BHK Flat in Sector 39 Gurgaon          flat
#
#                       society  price  price_per_sqft    area  \
# 3745  signature global solera   0.30          6134.0   489.0
# 1683              independent   9.19         34037.0  2700.0
# 963                ireo skyon   3.75         13392.0  2800.0
# 2055     emaar gurgaon greens   1.39          8424.0  1650.0
# 77               city heights   1.75          8750.0  2000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 3745  Super Built up area 602(55.93 sq.m.)Carpet are...        2         2
# 1683                        Plot area 300(250.84 sq.m.)       16        18
# 963              Super Built up area 2800(260.13 sq.m.)        4         5
# 2055             Super Built up area 1650(153.29 sq.m.)        3         3
# 77                     Carpet area: 2000 (185.81 sq.m.)        3         4
#
#      balcony           additionalRoom  \
# 3745       1            not available
# 1683       2  pooja room,servant room
# 963        3             servant room
# 2055       3             servant room
# 77         3             servant room
#
#                                                 address  floorNum facing  \
# 3745  Signature Global Solera, Sector-107 Gurgaon, S...       5.0   East
# 1683         342, Sushant Lok Phase 2, Gurgaon, Haryana       4.0   West
# 963           1502, Sector 60 Gurgaon, Gurgaon, Haryana      15.0  South
# 2055               Sector 102 Gurgaon, Gurgaon, Haryana       7.0   West
# 77                  Sector 39 Gurgaon, Gurgaon, Haryana       3.0    NaN
#
#         agePossession                                    nearbyLocations  \
# 3745  1 to 5 Year Old  ['Gurgaon Dreamz Mall', 'Dwarka Expressway', "...
# 1683  0 to 1 Year Old  ['Mg road metro station', 'Iffco chowk metro s...
# 963   1 to 5 Year Old  ['Sector 55-56 Metro', 'Golf Course Extension'...
# 2055  1 to 5 Year Old  ['JMS Marine Square Mall', 'Dwarka Expressway'...
# 77       10+ Year Old  ['Rajiv Chowk Mosque', 'Icici bank ATM', 'Stat...
#
#                                             description  \
# 3745  A beautiful 2 bhk apartment in sector-107, gur...
# 1683  This 16 bhk house for sale in sushant lok phas...
# 963   The three-Side-Open apartments give you a sens...
# 2055  Situated in sector 102 gurgaon, emaar gurgaon ...
# 77    City heights is one of the most popular destin...
#
#                                          furnishDetails  \
# 3745                                                NaN
# 1683  ['8 Wardrobe', '9 Fan', '1 Exhaust Fan', '3 Ge...
# 963                                                 NaN
# 2055  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '1 Ge...
# 77    ['1 Water Purifier', '5 Fan', '1 Fridge', '1 E...
#
#                                                features  \
# 3745  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1683  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 963   ['Centrally Air Conditioned', 'Water purifier'...
# 2055  ['Intercom Facility', 'Lift(s)', 'Maintenance ...
# 77    ['Feng Shui / Vaastu Compliant', 'Security / F...
#
#                                                  rating
# 3745  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 1683  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 963   ['Green Area5 out of 5', 'Construction5 out of...
# 2055  ['Green Area5 out of 5', 'Construction4 out of...
# 77    ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
# shape
df.shape
# Out:
# (3961, 20)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         3940 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
#  16  description      3961 non-null   object
#  17  furnishDetails   2929 non-null   object
#  18  features         3252 non-null   object
#  19  rating           3511 non-null   object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 619.0+ KB

# %%
# Null values
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               1
# price                20
# price_per_sqft       20
# area                 20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum             21
# facing             1177
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# dtype: int64

# %%
df.insert(loc=3, column='sector', value = df["property_name"].str.split('in').str.get(1).str.replace('Gurgaon', '').str.strip())

# %%
df["sector"]
# Out:
# 0          Sector 113
# 1           Sector 66
# 2           Sector 83
# 3           Sector 79
# 4         DLF Phase 1
#             ...
# 3956      DLF Phase 4
# 3957       Sector 107
# 3958    Rajendra Park
# 3959        Sector 71
# 3960        Sector 66
# Name: sector, Length: 3961, dtype: object

# %%
df['sector'] = df['sector'].str.lower()

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna                          163
# sector 102                     113
# sector 85                      110
# sector 92                      104
# sector 69                       94
#                               ...
# shivji park colony               1
# rattan garden                    1
# laxman vihar, railway road,      1
# civil l                          1
# jacobpura near sadar bazar       1
# Name: count, Length: 301, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

# %%
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

# %%
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna road    163
# sector 102    113
# sector 85     110
# sector 92     104
# sector 69      94
#              ...
# sector 17b      3
# sector 73       3
# sector 88b      3
# sector 27       3
# sector 17a      3
# Name: count, Length: 114, dtype: int64

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 3314  2 BHK Flat in New Gurgaon          flat                   green court
# 3502  4 BHK Flat in New Gurgaon          flat                    sare homes
# 3529  4 BHK Flat in New Gurgaon          flat                        dlf 76
# 3857  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
#
#      sector  price  price_per_sqft    area  \
# 3314    new   0.38          5507.0   690.0
# 3502    new   0.85          4786.0  1776.0
# 3529    new   4.00         11428.0  3500.0
# 3857    new   0.67          5583.0  1200.0
#
#                                 areaWithType  bedRoom  bathroom  ...  \
# 3314           Carpet area: 690 (64.1 sq.m.)        2         2  ...
# 3502     Super Built up area 1776(165 sq.m.)        4         4  ...
# 3529        Carpet area: 3500 (325.16 sq.m.)        4         4  ...
# 3857  Super Built up area 1200(111.48 sq.m.)        2         2  ...
#
#                additionalRoom                        address floorNum  facing  \
# 3314            not available  New Gurgaon, Gurgaon, Haryana      7.0     NaN
# 3502            not available  New Gurgaon, Gurgaon, Haryana      3.0     NaN
# 3529  study room,servant room  New Gurgaon, Gurgaon, Haryana      4.0     NaN
# 3857            not available  New Gurgaon, Gurgaon, Haryana      3.0     NaN
#
#            agePossession                                    nearbyLocations  \
# 3314  Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
# 3502    5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
# 3529            Jun 2027  ['Shri Balaji Hospital and Trauma Center', 'S....
# 3857     1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
#
#                                             description  \
# 3314  We are the proud owners of this 2 bhk apartmen...
# 3502  Located in the popular residential address of ...
# 3529  This lovely 4 bhk apartment/flat in new gurgao...
# 3857  Check out this 2 bhk apartment for sale in tak...
#
#                                          furnishDetails  \
# 3314                                                 []
# 3502                                                 []
# 3529  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 3857                                                 []
#
#                                                features rating
# 3314  ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN
# 3502                                                NaN    NaN
# 3529  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN
# 3857  ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN
#
# [4 rows x 21 columns]

# %%
df.loc[955,'sector'] = 'sector 37'
df.loc[2800,'sector'] = 'sector 92'
df.loc[2838,'sector'] = 'sector 90'
df.loc[2857,'sector'] = 'sector 76'

# %%
df[df['sector'] == 'new sector 2']
# Out:
#                                     property_name property_type  \
# 326   2 Bedroom House for sale in New Palam Vihar         house
# 607                 2 BHK Flat in New Palam Vihar          flat
# 2687                2 BHK Flat in New Palam Vihar          flat
# 2795                2 BHK Flat in New Palam Vihar          flat
# 3262  3 Bedroom House for sale in New Palam Vihar         house
#
#                   society        sector  price  price_per_sqft    area  \
# 326               my home  new sector 2   0.34         12592.0   270.0
# 607   ompee k s residency  new sector 2   1.60         26936.0   594.0
# 2687              my home  new sector 2   0.28          3166.0   884.0
# 2795              my home  new sector 2   0.22          4400.0   500.0
# 3262          independent  new sector 2   1.00          8796.0  1137.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 326                          Plot area 270(25.08 sq.m.)        2         2
# 607                       Carpet area: 66 (55.18 sq.m.)        2         2
# 2687                     Carpet area: 900 (83.61 sq.m.)        2         1
# 2795                     Carpet area: 500 (46.45 sq.m.)        2         2
# 3262  Plot area 120(100.34 sq.m.)Built Up area: 120 ...        3         2
#
#       ... additionalRoom                                            address  \
# 326   ...  not available         Ez-19 A, New Palam Vihar, Gurgaon, Haryana
# 607   ...  not available                  New Palam Vihar, Gurgaon, Haryana
# 2687  ...         others         F 150/b, New Palam Vihar, Gurgaon, Haryana
# 2795  ...  not available                  New Palam Vihar, Gurgaon, Haryana
# 3262  ...     pooja room  Q-148, New Palam Vihar, Phase-2, Near Royal Oa...
#
#      floorNum  facing     agePossession  \
# 326       3.0    West  5 to 10 Year Old
# 607       1.0     NaN   1 to 5 Year Old
# 2687      2.0     NaN   1 to 5 Year Old
# 2795      1.0     NaN   0 to 1 Year Old
# 3262      1.0   North      10+ Year Old
#
#                                         nearbyLocations  \
# 326   ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 607   ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2687  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2795  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3262  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 326   There are availability of various facilities l...
# 607   We are the proud owners of this 2 bhk apartmen...
# 2687  2 bhk room with wooden coverd ,1 drawing room,...
# 2795  Cctv surveillance are provided here. There is ...
# 3262  Ground and first floor, Ground floor: Ground f...
#
#                                          furnishDetails  \
# 326   ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
# 607                                                 NaN
# 2687  ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
# 2795  ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 3262                                                NaN
#
#                                           features  \
# 326   ['Water Storage', 'Park', 'Visitor Parking']
# 607                                            NaN
# 2687                     ['Water Storage', 'Park']
# 2795                                           NaN
# 3262                                           NaN
#
#                                                  rating
# 326   ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 607   ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2687  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2795  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 3262  ['Environment4 out of 5', 'Lifestyle4 out of 5...
#
# [5 rows x 21 columns]

# %%
df.loc[[311,1072,1486,3040,3875],'sector'] = 'sector 110'

# %%
df.shape
# Out:
# (3803, 21)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(122)

# %%
df.to_csv('cleaned_data/gurgaon_properties_cleaned_v1.csv',index=False)
