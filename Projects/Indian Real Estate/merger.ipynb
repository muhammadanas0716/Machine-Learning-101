# %%
import numpy as np 
import pandas as pd

# %%
flats = pd.read_csv('cleaned_data/flats_cleaned.csv')
houses = pd.read_csv('cleaned_data/house_cleaned.csv')

print("Datasets loaded.")
# Out:
# Datasets loaded.

# %%
df = pd.concat([flats, houses], ignore_index=True)

# %%
df = df.sample(df.shape[0], ignore_index=True)

# %%
df.head()
# Out:
#                                        property_name property_type  \
# 0  7 Bedroom House for sale in Ashok Vihar Phase ...         house
# 1                    3 BHK Flat in Sector 56 Gurgaon          flat
# 2                    3 BHK Flat in Sector 68 Gurgaon          flat
# 3                    3 BHK Flat in Sector 61 Gurgaon          flat
# 4                   3 BHK Flat in Sector 82A Gurgaon          flat
#
#                            society  price  price_per_sqft    area  \
# 0  ashok vihar phase iii extension   0.40          8889.0   450.0
# 1          professors enclave cghs   1.54          8324.0  1850.0
# 2                       m3m ikonic   1.78          9128.0  1950.0
# 3              smart world orchard   2.24         14460.0  1549.0
# 4                   dlf the primus   1.87         10394.0  1799.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                          Plot area 50(41.81 sq.m.)        7         4
# 1  Super Built up area 2000(185.81 sq.m.)Built Up...        3         3
# 2  Super Built up area 1950(181.16 sq.m.)Built Up...        3         3
# 3             Super Built up area 1549(143.91 sq.m.)        3         3
# 4  Super Built up area 1799(167.13 sq.m.)Carpet a...        3         3
#
#   balcony           additionalRoom  \
# 0      3+               pooja room
# 1       2  pooja room,servant room
# 2      3+            not available
# 3       2                   others
# 4       3               pooja room
#
#                                              address  floorNum facing  \
# 0  House No.183, Street Number 7, Ashok Vihar Pha...       4.0    NaN
# 1     Sector 56, Sector 56 Gurgaon, Gurgaon, Haryana       6.0  South
# 2           T-5, Sector 68 Gurgaon, Gurgaon, Haryana      27.0  South
# 3  Smartworld Orchard Sector 61, Golf Course Ext....       3.0    NaN
# 4          198, Sector 82A Gurgaon, Gurgaon, Haryana      31.0   East
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1      10+ Year Old  ['Sector metro station', 'Sector metro station...
# 2   1 to 5 Year Old  ['Airia Mall', 'Sohna Road', 'Vidyamrat Public...
# 3   Within 6 months  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4  5 to 10 Year Old  ['Sapphire 83', 'NH 48', 'Cambridge Montessori...
#
#                                          description  \
# 0  It's a newly built house which has 4 floors, 1...
# 1  This 3 bhk apartment is available for sale in ...
# 2  M3m ikonic in sector 68, gurgaon is a ready-To...
# 3  Residential apartment for sell.Located in sect...
# 4  This 3 bhk apartment is available for sale in ...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '15 Light', '1 Wardrobe', 'No AC', '...
# 1  ['5 Fan', '1 Exhaust Fan', '3 Geyser', '12 Lig...
# 2  ['3 Wardrobe', '6 Fan', '1 Exhaust Fan', '3 Ge...
# 3                                                 []
# 4                                                NaN
#
#                                             features  \
# 0                                  ['Water Storage']
# 1  ['Feng Shui / Vaastu Compliant', 'Lift(s)', 'H...
# 2  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 3                                                NaN
# 4  ['Power Back-up', 'Intercom Facility', 'Lift(s...
#
#                                               rating
# 0  ['Environment3 out of 5', 'Lifestyle4 out of 5...
# 1  ['Environment4 out of 5', 'Lifestyle5 out of 5...
# 2  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3                                                NaN
# 4  ['Green Area5 out of 5', 'Construction4.5 out ...
