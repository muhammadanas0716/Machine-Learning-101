# %%
import numpy as np 
import pandas as pd

# %%
flats = pd.read_csv('cleaned_data/flats_cleaned.csv')
houses = pd.read_csv('cleaned_data/house_cleaned.csv')

print("Datasets loaded.")
# Out:
# Datasets loaded.

# %%
df = pd.concat([flats, houses], ignore_index=True)

# %%
df = df.sample(df.shape[0], ignore_index=True)

# %%
df.head()
# Out:
#                              property_name property_type  \
# 0         2 BHK Flat in Sector 113 Gurgaon          flat
# 1          3 BHK Flat in Sector 66 Gurgaon          flat
# 2          3 BHK Flat in Sector 83 Gurgaon          flat
# 3          3 BHK Flat in Sector 79 Gurgaon          flat
# 4  5 Bedroom House for sale in DLF Phase 1         house
#
#                     society  price  price_per_sqft    area  \
# 0      tata gurgaon gateway   1.75         10443.0  1676.0
# 1  emaar mgf the palm drive   2.85         14615.0  1950.0
# 2            vatika gurgaon   1.25          6313.0  1980.0
# 3                    godrej   2.00          8453.0  2366.0
# 4               independent   4.50         33333.0  1350.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 1580(146.79 sq.m.)        2         2
# 1  Super Built up area 1950(181.16 sq.m.)Built Up...        3         3
# 2  Super Built up area 1980(183.95 sq.m.)Built Up...        3         3
# 3                   Carpet area: 2366 (219.81 sq.m.)        3         4
# 4                        Plot area 150(125.42 sq.m.)        5         5
#
#   balcony additionalRoom                                       address  \
# 0       2     study room    N/a, Sector 113 Gurgaon , Gurgaon, Haryana
# 1       3     study room           Sector 66 Gurgaon, Gurgaon, Haryana
# 2       2   servant room  Block B, Sector 83 Gurgaon, Gurgaon, Haryana
# 3      3+   servant room           Sector 79 Gurgaon, Gurgaon, Haryana
# 4      3+  not available                 DLF Phase 1, Gurgaon, Haryana
#
#    floorNum      facing     agePossession  \
# 0      10.0       North   1 to 5 Year Old
# 1      11.0  North-East   1 to 5 Year Old
# 2      12.0       North  5 to 10 Year Old
# 3       2.0  North-East   1 to 5 Year Old
# 4       2.0         NaN      10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Dwarka Sector 21 Metro Station', 'Gurgaon Dr...
# 1  ['Sector 55-56 Rapid Metro Station', 'HUB 66',...
# 2  ['Huda Metro Station (Gurugram)', 'Sapphire 83...
# 3  ['Vatika Town Square-INXT', 'Naurangpur Road',...
# 4  ['Guru dronacharya metro station', 'Dlf phase ...
#
#                                          description  \
# 0  Tata gurgaon gateway is one of the most popula...
# 1  Why you should consider emaar mgf the palm dri...
# 2  Check out this 3 bhk apartment for sale in vat...
# 3  Made with personal taste. Hitachi ac, faber ch...
# 4  Property is located in prime location of dlf 1...
#
#                                       furnishDetails  \
# 0                                                 []
# 1  ['3 Wardrobe', '5 Fan', '3 Geyser', '10 Light'...
# 2                                                NaN
# 3  ['1 Water Purifier', '5 Fan', '1 Exhaust Fan',...
# 4                                                NaN
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1  ['Power Back-up', 'Intercom Facility', 'Lift(s...
# 2  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 3  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 4                                  ['Water Storage']
#
#                                               rating
# 0  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 1  ['Green Area5 out of 5', 'Construction4.5 out ...
# 2  ['Green Area5 out of 5', 'Construction4.5 out ...
# 3  ['Green Area5 out of 5', 'Construction5 out of...
# 4  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
df.to_csv("gurgaon_properties.csv", index=False)

# %%
df = pd.read_csv("gurgaon_properties.csv")
df.shape
# Out:
# (3961, 20)
